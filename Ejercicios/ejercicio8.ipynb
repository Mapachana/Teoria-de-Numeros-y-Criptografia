# %% [markdown]
# # Ejercicio 8
#
# > Por: Mapachana
#
# **Toma tu número n de la lista publicada para este ejercicio.**

# %%
n = 2844871984646731064442373175299276800091
n
# Out:
# 2844871984646731064442373175299276800091

# %%
import math

# %% [markdown]
# **i) Pasa algunos tests de primalidad para ver si n es compuesto.**

# %% [markdown]
# Comenzamos pasando el test de Fermat para las bases $\{2,3,5,7,11\}$:

# %%
primos = [2,3,5,7,11]

for p in primos:
    print(pow(2, n-1, n))
# Out:
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# Luego $n$ es posible primo de Fermat para todas las bases.
#
# Ahora vamos a pasarle el test de Miller-Rabin

# %%
def calcular_r(num):
    r = 0
    while num % 2 == 0:
        r += 1
        num = num//2
    return r

def a_suc(base, num):
    r = calcular_r(num-1)
    n = (num-1)//pow(2,r)
    
    #print(r)
    sucesion = []
    
    for i in range (0,r+1):
        aux = pow(2,i)
        exp = int(n*aux)
        sucesion.append(pow(base, exp, num))        
    return sucesion

# %%
(n-1)//2
# Out:
# 1422435992323365532221186587649638400045

# %%
print(n-1)

for p in primos:
    print("La a-sucesion obtenida para la base {} es:".format(p))
    print(a_suc(p, n))
    print("")
# Out:
# 2844871984646731064442373175299276800090
# La a-sucesion obtenida para la base 2 es:
# [2844871984646731064442373175299276800090, 1]
#
# La a-sucesion obtenida para la base 3 es:
# [2844871984646731064442373175299276800090, 1]
#
# La a-sucesion obtenida para la base 5 es:
# [1, 1]
#
# La a-sucesion obtenida para la base 7 es:
# [1, 1]
#
# La a-sucesion obtenida para la base 11 es:
# [2844871984646731064442373175299276800090, 1]

# %% [markdown]
# Como $2844871984646731064442373175299276800090\equiv -1 \mod n$ tenemos que $n$ pasa el test de Miller-Rabin para los 5 primeros primos, pues las sucesiones acaban en 1 y todo 1 va precedido de otro 1 o de -1.

# %% [markdown]
# **ii) En caso que tu n sea probable primo. Factoriza n + 1 encontrando certificadosde primalidad para los factores mayores de 10000.**

# %% [markdown]
# Aplicamos rho de Polard a n+1:

# %%
def f(x):
    return pow(x,2)+1

def rho_polar(n, x0, t0):
    x = x0
    y = x
    t = t0
    i = 0
    g= '-'
    print("Paso: {}, x: {}, y: {}, g: {}".format(i,x,y,g))
    while i < t:
        i = i+1
        x = pow(f(x),1,n)
        y = pow(f(f(y)),1,n)
        g = math.gcd(x-y, n)
        print("Paso: {}, x: {}, y: {}, g: {}".format(i,x,y,g))
        if 1 < g and g < n:
            print("g: {}".format(g))
            print("Iteraciones necesarias {}".format(i))
            
            return g, i
    
    print("No hay divisores con t iteraciones")
    return "No hay divisores con t iteraciones"

# %%
m = n+1
i = 0
factores = []

while pow(m, 1, 2) == 0:
    i += 1
    m = m//2
    factores.append(2)


print(i)
print(m)
print(factores)

2*2*711217996161682766110593293824819200023 == n+1
# Out:
# 2
# 711217996161682766110593293824819200023
# [2, 2]
# True

# %%
itotal = 0
g, i = rho_polar(m, 1, 100)
factores.append(g)
m = m//g
itotal = itotal + i

#factores.append(m)
print(m)
print(factores)
print(itotal)

2*2*31*22942516005215573100341719155639329033 == n+1
# Out:
# Paso: 0, x: 1, y: 1, g: -
# Paso: 1, x: 2, y: 5, g: 1
# Paso: 2, x: 5, y: 677, g: 1
# Paso: 3, x: 26, y: 210066388901, g: 31
# g: 31
# Iteraciones necesarias 3
# 22942516005215573100341719155639329033
# [2, 2, 31]
# 3
# True

# %%
g, i = rho_polar(m, 1, 1000)
factores.append(g)
m = m//g
itotal = itotal + i

#factores.append(m)
print(m)
print(factores)
print(itotal)

2*2*31*63929*358874939467465048731275620698577 == n+1
# Out:
# Paso: 0, x: 1, y: 1, g: -
# Paso: 1, x: 2, y: 5, g: 1
# Paso: 2, x: 5, y: 677, g: 1
# Paso: 3, x: 26, y: 210066388901, g: 1
# Paso: 4, x: 677, y: 20135595133298421268569779278530825093, g: 1
# Paso: 5, x: 458330, y: 674788722746993047415634074439513219, g: 1
# Paso: 6, x: 210066388901, y: 3892251287431005711728934699887612429, g: 1
# Paso: 7, x: 44127887745906175987802, y: 20380127971868121553970008132038311275, g: 1
# Paso: 8, x: 20135595133298421268569779278530825093, y: 19946228231277923797745759985033243527, g: 1
# Paso: 9, x: 18063929073351459209073404676064964323, y: 19319423095077092049667638860204806901, g: 1
# Paso: 10, x: 674788722746993047415634074439513219, y: 21239990581398739567805656779350752002, g: 1
# Paso: 11, x: 21335031150999976921698161111922023375, y: 13406691699347664153231066574364537179, g: 1
# Paso: 12, x: 3892251287431005711728934699887612429, y: 14995024783987801347685729189285367431, g: 1
# ...

# %% [markdown]
# COMPROBAR 63929 PRIMO

# %%
print(m)
g, i = rho_polar(m, 1, 1000000)
factores.append(g)
m = m//g
itotal = itotal + i

#factores.append(m)
print(m)
print(factores)
print(itotal)
# Out:
# 358874939467465048731275620698577
# Paso: 0, x: 1, y: 1, g: -
# Paso: 1, x: 2, y: 5, g: 1
# Paso: 2, x: 5, y: 677, g: 1
# Paso: 3, x: 26, y: 210066388901, g: 1
# Paso: 4, x: 677, y: 198904597359779404098027995765354, g: 1
# Paso: 5, x: 458330, y: 103836548158755800835907526188459, g: 1
# Paso: 6, x: 210066388901, y: 252568906347258238250593411544864, g: 1
# Paso: 7, x: 44127887745906175987802, y: 337909389716366618328183807520599, g: 1
# Paso: 8, x: 198904597359779404098027995765354, y: 317970615683854310192262227032444, g: 1
# Paso: 9, x: 317870196073446233377583822789605, y: 108478725046081316878371138311260, g: 1
# Paso: 10, x: 103836548158755800835907526188459, y: 336163956288123693840443926170834, g: 1
# Paso: 11, x: 274874598647239672556737012319302, y: 200585661572327776803211927796190, g: 1
# Paso: 12, x: 252568906347258238250593411544864, y: 153188218709216546839929636724640, g: 1
# Paso: 13, x: 49041125595312136303865331748519, y: 60289020473361579088451389523791, g: 1
# ...

# %% [markdown]
# COMRPOBAR 600702031 ES PRIMO

# %%
print(m)
'''g, i = rho_polar(597425879965877872537567, 1, 10000)
factores.append(g)
m = 597425879965877872537567//g
itotal = itotal + i

factores.append(m)
print(m)
print(factores)
print(itotal)'''

factores.append(352173733409)
factores.append(1696395339263)
print(factores)

acu = 1
for num in factores:
    acu = acu*num
    
acu == n+1
# Out:
# 597425879965877872537567
# [2, 2, 31, 63929, 600702031, 352173733409, 1696395339263]
# True

# %%
# Out:
# False

# %% [markdown]
# **iii) Con P = 1, encuentra el menor Q natural mayor o igual que 2, tal que defina una s.L. que certifique la primalidad de n.**

# %%
def calcular_digitos(b):
    digitos = []
    
    while b != 1:
        resto = pow(b,1,2)
        digitos.append(int(resto))
        b = (b-resto)//2
    
    digitos.append(1)
    
    digitos = list(reversed(digitos))
        
    return digitos

# %%
def suc_lucas_div(n, p, q, m):
    r = int(n+1)//m # solo porque en este caso el jacobi es -1
    digitos = calcular_digitos(r)
    
    U = [-1, -1]
    U[0], U[1] = 0, 1
    
    U_nuevo = [-1, -1]
    V = -1
    
    V = 2*U[1]-p*U[0]
    
    j = 0
    digit = 0

    while digit < len(digitos):
        
        if digitos[digit] == 0:
            aux = 2*U[0]*U[1]-p*pow(U[0], 2)
            aux = pow(aux, 1, n)
            U_nuevo[0] = aux
            
            aux = pow(U[1], 2)-q*pow(U[0], 2)
            aux = pow(aux, 1, n)
            U_nuevo[1] = aux
            
            V = pow(2*U_nuevo[1]-p*U_nuevo[0],1,n)
            
            if digit >= len(digitos)-1:
                print("\n\n")
                print("U[{}] = {}, \nV[{}] = {}, \n\nU[{}] = {}\n".format(2*j, U_nuevo[0], 2*j, V, 2*j+1, U_nuevo[1]))
                return U_nuevo[0]
                
            j = 2*j
        else:
            aux = pow(U[1], 2)-q*pow(U[0], 2)
            aux = pow(aux, 1, n)
            U_nuevo[0] = aux
            
            aux = p*pow(U[1],2)-2*q*U[0]*U[1]
            aux = pow(aux, 1, n)
            U_nuevo[1] = aux
            
            V = pow(2*U_nuevo[1]-p*U_nuevo[0],1,n)
            
            if digit >= len(digitos)-1:
                print("\n\n")
                print("U[{}] = {}, \nV[{}] = {}, \n\nU[{}] = {}\n".format(2*j+1, U_nuevo[0], 2*j+1, V, 2*j+2, U_nuevo[1]))
                return U_nuevo[0]
                
            j = 2*j+1
            
                     
        U[0], U[1] = U_nuevo[0], U_nuevo[1]
        
        digit += 1

# %%
print(factores)
factores = [ 2, 31, 63929, 600702031, 352173733409, 1696395339263]
print(factores)
# Out:
# [2, 31, 63929, 600702031, 352173733409, 1696395339263]
# [2, 31, 63929, 600702031, 352173733409, 1696395339263]

# %%
P = 1
print(n)

for Q in range(2,5):
    print("\n\n")
    print("Q: {}".format(Q))

    num_r = suc_lucas_div(n, P, int(Q), 1)
    print(num_r)
    if (num_r == 0):
        print("entro")
        for elem in factores:
            print((n+1)//elem)
            print("Factor: {}".format(elem))
            suc_lucas_div(n, P, int(Q), elem)
# Out:
# 2844871984646731064442373175299276800091
#
#
#
# Q: 2
#
#
#
# U[2844871984646731064442373175299276800092] = 0,
# V[2844871984646731064442373175299276800092] = 4,
#
# U[2844871984646731064442373175299276800093] = 2
#
# 0
# entro
# 1422435992323365532221186587649638400046
# Factor: 2
#
#
#
# U[1422435992323365532221186587649638400046] = 2401816336829289298745644029101509733749,
# V[1422435992323365532221186587649638400046] = 0,
#
# U[1422435992323365532221186587649638400047] = 2623344160738010181594008602200393266920
#
# 91770064020862292401366876622557316132
# Factor: 31
#
#
#
# U[91770064020862292401366876622557316132] = 1470916208500242344757444167006191571594,
# V[91770064020862292401366876622557316132] = 182521758238274725190305369534832625726,
#
# U[91770064020862292401366876622557316133] = 826718983369258534973874768270512098660
#
# 44500492493965666042678176966623548
# Factor: 63929
#
#
#
# U[44500492493965666042678176966623548] = 1641957773477697682672844736651862712136,
# ...

# %% [markdown]
# Para P=1, Q=2 tenemos que ningún $U_{\frac{r}{p}}\equiv 0\mod n$ y $U_r\equiv 0\mod n$, luego tenemos que el rango de $n$ es $n+1$ y por tanto es primo.
